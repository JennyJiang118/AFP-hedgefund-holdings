# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # utils

# %%
def alpha_transform(data: pd.DataFrame, col: str, max_value: float):
    data = data.reset_index().set_index("date")
    data["mean"] = data.groupby("date")[col].mean()
    data["std"] = data.groupby("date")[col].std()
    data["zscore"] = np.minimum(max_value,np.maximum(-max_value,(data[col] - data["mean"]) / data["std"])).fillna(0)
    data = data.reset_index().set_index(['date', 'permno'])
    return data["zscore"]


def feature_clip(x, col, qmin, qmax):
    return x[col].clip(x[col].quantile(qmin),x[col].quantile(qmax))


def get_quantile_returns(frame, signal_col, n_bins, ret):
    frame[f'{signal_col}Group'] = pd.qcut(frame[signal_col], n_bins, labels=[i + 1 for i in range(n_bins)])
    return frame.groupby(f'{signal_col}Group')[ret].mean()


def get_long_only_returns(frame, signal_col, perc, ret):
    edge = frame[signal_col].quantile(1-perc)
    return frame[frame[signal_col] > edge][ret].mean()


def get_long_only_weight(frame, signal_col, nbins):
    label = frame.groupby('date')[signal_col].transform(lambda x: pd.qcut(x, nbins, labels=range(1, nbins+1))).to_frame()
    label.columns = ['label']
    cnts = label.groupby('date')['label'].transform(lambda x: (x==nbins).sum())
    label = label.join(frame['future_ret'])
    label['weight'] = 0
    label.loc[label['label']==nbins, 'weight'] = 1/cnts
    return label[['weight', 'future_ret']].dropna(subset=['future_ret'])


def get_long_short_returns(frame, signal_col, perc, ret):
    edge_short = frame[signal_col].quantile(perc)
    edge_long = frame[signal_col].quantile(1-perc)
    return frame[frame[signal_col] > edge_long][ret].mean() - frame[frame[signal_col] <= edge_short][ret].mean()


def get_long_short_weight(frame, signal_col, perc, ret):
    edge_short = frame[signal_col].quantile(perc)
    edge_long = frame[signal_col].quantile(1-perc)
    cnt_long = frame[frame[signal_col] > edge_long].shape[0]
    cnt_short = frame[frame[signal_col] <= edge_short].shape[0]
    frame['weight'] = 0
    frame[frame[signal_col] > edge, 'weight'] = 1/cnt_long
    frame[frame[signal_col] <= edge, 'weight'] = 1/cnt_short
    return frame['weight']


def backtest(daily_ret: pd.DataFrame, name: str):
    start_date = daily_ret.index[0].date()
    end_date = daily_ret.index[-1].date()
    ret = daily_ret.mean() * 4
    std = daily_ret.std() * np.sqrt(4)
    n_date = daily_ret.shape[0]
    n_pos_date = (daily_ret>0).sum()
    mdd = (daily_ret.cumsum().cummax() - daily_ret.cumsum()).max()
    sharp = ret / std
    stats_dict = { 'start_date' : start_date,
                   'end_date': end_date,
                   'n_quarter': n_date,
                   'n_pos_quarter' : n_pos_date,
                   'ret_annual': ret,
                   'std_annual': std,
                   'shape': sharp,
                   'mdd': mdd}
    stats = pd.DataFrame(stats_dict)
    return stats

# %% [markdown]
# ## Get data

# %%
import pyarrow.parquet as pq

# Specify the path to your parquet.gzip file
parquet_file_path = '../data/hf_netflow.parquet.gzip'

# Read the Parquet file using pyarrow
net_flow = pq.read_table(parquet_file_path)

# Convert the table to a Pandas DataFrame if needed
net_flow = net_flow.to_pandas()

net_flow.head()
# Out:
#        rdate  mgrno                       mgrname  first_report  last_report  \
# 0 2015-03-31  127.0  AEW CAPITAL MANAGEMENT, L.P.         False        False
# 1 2015-06-30  127.0  AEW CAPITAL MANAGEMENT, L.P.         False        False
# 2 2015-09-30  127.0  AEW CAPITAL MANAGEMENT, L.P.         False        False
# 3 2015-12-31  127.0  AEW CAPITAL MANAGEMENT, L.P.         False        False
# 4 2016-03-31  127.0  AEW CAPITAL MANAGEMENT, L.P.         False        False
#
#         assets      pret        tbuys      tsales       tgain  tgainret  \
# 0  4553.577546 -0.097883          NaN         NaN         NaN       NaN
# 1  4102.561959  0.036171  4051.512488    0.000000  146.225932  0.036092
# 2  4064.568036  0.084079   136.028707  411.538853  -22.560811 -0.041202
# 3  4502.353836  0.060149   641.889624  270.084462   42.346158  0.046434
# 4  4568.146306  0.046889    59.260200  189.999783   -4.934305 -0.019796
#
#      netflows  turnover1  turnover2  turnover3
# 0         NaN        NaN        NaN        NaN
# 1   -5.295758   0.000000   0.001163   0.888580
# 2 -186.386535   0.033311   0.078589   0.088038
# 3   96.041597   0.063053   0.090077   0.200743
# 4 -205.019623   0.013067   0.058698   0.009826

# %%
# Specify the path to your parquet.gzip file
parquet_file_path = '../data/holdings_all_hf.parquet.gzip'

# Read the Parquet file using pyarrow
holdings = pq.read_table(parquet_file_path)

# Convert the table to a Pandas DataFrame if needed
holdings = holdings.to_pandas()

# merge with net flow
# holdings.rename(columns = {'date': 'rdate'}, inplace=True)
# holdings = holdings.merge(net_flow[['rdate', 'mgrno', 'assets']], on=['rdate', 'mgrno'], how='left')

# set index
holdings = holdings.reset_index().set_index(['date', 'mgrno', 'permno']).sort_index()

holdings.head()
# Out:
#                          first_report  last_report     shares  shares_adj  \
# date       mgrno permno
# 2015-06-30 127.0 12756          False        False  1792286.0   1792286.0
#                  14037          False        False  3373100.0   3373100.0
#                  14061          False        False  1029700.0   1029700.0
#                  15052          False        False  1701800.0   1701800.0
#                  15194          False        False   439300.0    439300.0
#
#                            phrdate  pshares_adj     trade  qtrgap  lpermno  \
# date       mgrno permno
# 2015-06-30 127.0 12756  2015-03-31    1771986.0   20300.0     1.0  12513.0
#                  14037  2015-03-31    3082300.0  290800.0     1.0  14036.0
#                  14061  2015-03-31     978300.0   51400.0     1.0  14039.0
#                  15052  2015-03-31    1195300.0  506500.0     1.0  15048.0
#                  15194  2015-03-31     576000.0 -136700.0     1.0  15142.0
#
#                          npermno   modtrade  buysale    year    prc  \
# date       mgrno permno
# 2015-06-30 127.0 12756   12756.0  1792286.0      1.0  2015.0  29.78
#                  14037   14037.0  3373100.0      1.0  2015.0  14.58
#                  14061   14061.0  1029700.0      1.0  2015.0  16.04
#                  15052   15052.0  1701800.0      1.0  2015.0  20.10
#                  15194   15194.0   439300.0      1.0  2015.0  15.92
#
#                                vol  openprc   askhi   bidlo       ret  \
# date       mgrno permno
# 2015-06-30 127.0 12756   1334009.0   29.870  29.980  29.500  0.005062
#                  14037    438653.0   14.580  14.730  14.430  0.003441
#                  14061   2427100.0   15.970  16.251  15.890  0.006905
#                  15052    494474.0   20.440  20.440  19.980 -0.007897
#                  15194     51041.0   15.812  15.940  15.665  0.005685
#
#                            shrout  yyyy-mm  mkt_port_weight        gics  \
# date       mgrno permno
# 2015-06-30 127.0 12756   132182.0  2015-06              0.0  40402035.0
#                  14037    55353.0  2015-06              0.0  40402020.0
#                  14061   210852.0  2015-06              0.0  40402050.0
#                  15052   126851.0  2015-06              0.0  40402010.0
#                  15194    24168.0  2015-06              0.0  40402040.0
#
#                                                 comnam ticker       gics1  \
# date       mgrno permno
# 2015-06-30 127.0 12756             R L J LODGING TRUST    RLJ  Financials
#                  14037   REXFORD INDUSTRIAL REALTY INC   REXR  Financials
#                  14061           AMERICAN HOMES 4 RENT    AMH  Financials
#                  15052              STORE CAPITAL CORP   STOR  Financials
#                  15194   EASTERLY GOVERNMENT PPTYS INC    DEA  Financials
#
#                            gics2
# date       mgrno permno
# 2015-06-30 127.0 12756   Unknown
#                  14037   Unknown
#                  14061   Unknown
#                  15052   Unknown
#                  15194   Unknown

# %% [markdown]
# ## time series change of holdings: per manager, per stock

# %% [markdown]
# 1. buysale: buy = 1, sale = -1 (terminal sale should be fixed)
# 2. weight: value of a stock / value of the whole portfolio of this institution
# 3. weight_diff: quarterly difference of stock weight in the portfolio of this institution
# 4. share_chg: percentage change of share holdings on a stock of this institution
# 5. value_chg: percentage change of value holdings on a stock of this institution

# %%
# signal 1: buysale
# holdings['buysale'] = np.where(holdings['buysale']==1, holdings['buysale']*10, holdings['buysale']) # scale the initial buy
holdings.loc[holdings.index.get_level_values(0) == holdings.index.get_level_values(0).min(), 'buysale'] = 0  # the start of data cannot be treated as initial buy
holdings['buysale'] = np.sign(holdings['buysale'])

# signal 2: weight and weight diff
holdings['value'] = holdings['shares']*holdings['prc']
holdings['portfolio_value'] = holdings.groupby(['date', 'mgrno'])['value'].transform('sum')
holdings['weight'] = holdings['value'] / holdings['portfolio_value'] - holdings['mkt_port_weight']
holdings['weight_diff'] = holdings.groupby(['mgrno', 'permno'])['weight'].diff()
holdings['weight_diff'] = np.where(holdings['buysale']==1, holdings['weight'], holdings['weight_diff'])

# noise: trade_dollar / value of the whole portfolio of this institution
holdings['trade_dollar'] = holdings['trade'] * holdings['prc']
holdings['trade_dollar_pct'] = holdings['trade_dollar'] / holdings['portfolio_value']

# signal 3: value change
holdings['share_chg'] = holdings['trade'] / (holdings['shares'] - holdings['trade'])
holdings['value_chg'] = holdings.groupby(['mgrno', 'permno'])['value'].pct_change()

# %% [markdown]
# ## time series change of holdings: per stock

# %%
# signal 4: mgr cnt ratio change
#shares_ratio = holdings.groupby(['date', 'permno']).agg({'shares':'sum', 'shrout':'mean'})
#shares_ratio['mgr_shares_ratio'] = shares_ratio['shares'] / shares_ratio['shrout']
mgrno_cnt = holdings.reset_index().set_index(['date', 'permno']).groupby(['date', 'permno'])['mgrno'].count()
mgrno_cnt.name = 'mgrno_cnt'
total_mgrno_cnt = holdings.reset_index().groupby(['date'])['mgrno'].count()
total_mgrno_cnt.name = 'total_mgrno_cnt'
mgrno_cnt = total_mgrno_cnt.to_frame().join(mgrno_cnt)
mgrno_cnt['mgrno_cnt_ratio'] = mgrno_cnt['mgrno_cnt'] / mgrno_cnt['total_mgrno_cnt']
mgrno_cnt['mgrno_cnt_ratio_chg'] = mgrno_cnt.groupby('permno')['mgrno_cnt_ratio'].pct_change()
mgrno_cnt['mgrno_cnt_ratio_chg'].replace([np.inf, -np.inf], 0, inplace=True)

# signal 3: value change
# take log
# bug: negative prc
total_value = holdings.groupby(['date', 'permno'])['value'].sum()
total_value.name = 'total_value'
total_value = total_value.to_frame()
total_value['value_chg'] = total_value.groupby('permno')['total_value'].pct_change()
total_value['value_chg'] = np.where(total_value['total_value']==0, 0, total_value['value_chg'])
total_value['value_chg'].replace([np.inf, -np.inf], 0, inplace=True)

# calculate signal average among all mgrs
holdings_stk = holdings.groupby(['date', 'permno']).agg({'weight':'mean', 'weight_diff': 'mean', 'buysale': 'mean', 'ret': 'last'})

# signal 1: weight change
holdings_stk['weight_chg'] = holdings_stk.groupby('permno')['weight'].pct_change()
holdings_stk['weight_chg'].replace([np.inf, -np.inf], 0, inplace=True)
holdings_stk = holdings_stk.join(mgrno_cnt[['mgrno_cnt_ratio', 'mgrno_cnt_ratio_chg']])
holdings_stk = holdings_stk.join(total_value)

# %%
# clip signals if necessary
holdings_stk['weight_diff'] = feature_clip(holdings_stk, 'weight_diff', 0.01, 0.99)

# %% [markdown]
# # performance

# %% [markdown]
# rank corr of raw features

# %%
holdings_stk['future_ret'] = holdings_stk['ret'].unstack().shift(-1).stack()
holdings_stk.drop(columns = ['ret', 'total_value']).corr('spearman')
# Out:
#                        weight  weight_diff   buysale  weight_chg  \
# weight               1.000000     0.667473  0.026827    0.147738
# weight_diff          0.667473     1.000000  0.172551    0.461664
# buysale              0.026827     0.172551  1.000000   -0.011645
# weight_chg           0.147738     0.461664 -0.011645    1.000000
# mgrno_cnt_ratio      0.023444     0.083842 -0.290066    0.008089
# mgrno_cnt_ratio_chg  0.112617     0.091722  0.342217   -0.025505
# value_chg            0.111209     0.191941  0.142372    0.323397
# future_ret           0.055088     0.028250 -0.054211    0.009239
#
#                      mgrno_cnt_ratio  mgrno_cnt_ratio_chg  value_chg  \
# weight                      0.023444             0.112617   0.111209
# weight_diff                 0.083842             0.091722   0.191941
# buysale                    -0.290066             0.342217   0.142372
# weight_chg                  0.008089            -0.025505   0.323397
# mgrno_cnt_ratio             1.000000            -0.013819  -0.039149
# mgrno_cnt_ratio_chg        -0.013819             1.000000   0.297060
# value_chg                  -0.039149             0.297060   1.000000
# future_ret                  0.008850             0.013775   0.024249
#
#                      future_ret
# weight                 0.055088
# weight_diff            0.028250
# buysale               -0.054211
# weight_chg             0.009239
# mgrno_cnt_ratio        0.008850
# mgrno_cnt_ratio_chg    0.013775
# value_chg              0.024249
# future_ret             1.000000

# %% [markdown]
# corr of raw features and zscore

# %%
features = ['weight', 'weight_diff', 'weight_chg', 'mgrno_cnt_ratio', 'mgrno_cnt_ratio_chg', 'value_chg', 'buysale']
for feature in features:
    holdings_stk[f'{feature}_zscore'] = alpha_transform(holdings_stk, feature, 10000)
holdings_stk.corr()['future_ret']
# Out:
# weight                        0.033780
# weight_diff                   0.026580
# buysale                      -0.030036
# ret                           0.013700
# weight_chg                   -0.012021
# mgrno_cnt_ratio              -0.011318
# mgrno_cnt_ratio_chg           0.003757
# total_value                  -0.026855
# value_chg                    -0.001408
# future_ret                    1.000000
# weight_zscore                 0.027283
# weight_diff_zscore            0.020508
# weight_chg_zscore             0.024247
# mgrno_cnt_ratio_zscore       -0.025757
# mgrno_cnt_ratio_chg_zscore    0.004953
# value_chg_zscore              0.013478
# buysale_zscore                0.006147
# Name: future_ret, dtype: float64

# %% [markdown]
# ic (for report)

# %%
ic1 = holdings_stk[['weight_zscore', 'weight_diff_zscore', 'value_chg_zscore', 'mgrno_cnt_ratio_zscore', 'future_ret']].corr()[['future_ret']].rename(columns={'future_ret': 'IC'})
ic2 = holdings_stk[['weight_zscore', 'weight_diff_zscore', 'value_chg_zscore', 'mgrno_cnt_ratio_zscore', 'future_ret']].corr('spearman')[['future_ret']].rename(columns={'future_ret': 'rank_IC'})
ic = ic1.join(ic2).iloc[:-1]
ic.index = ['weight', 'weight_diff', 'value_chg', 'mgrno_cnt_ratio_chg']
ic
# Out:
#                            IC   rank_IC
# weight               0.027283  0.065347
# weight_diff          0.020508  0.043700
# value_chg            0.013478  0.023894
# mgrno_cnt_ratio_chg -0.025757 -0.022730

# %% [markdown]
# statistics

# %%
stats = holdings_stk.drop(columns = ['ret', 'total_value','mgrno_cnt_ratio']).describe()[['weight_zscore', 'weight_diff_zscore', 'value_chg_zscore', 'mgrno_cnt_ratio_chg_zscore']]
stats.columns = ['wight', 'weight_diff', 'value_chg', 'mgr_cnt_ratio_chg']

# %%
stats
# Out:
#               wight   weight_diff     value_chg  mgr_cnt_ratio_chg
# count  5.332500e+04  5.332500e+04  5.332500e+04       5.332500e+04
# mean  -1.519022e-17  8.794340e-18  4.930161e-18      -3.197942e-18
# std    9.997280e-01  9.856064e-01  9.800634e-01       9.800443e-01
# min   -2.928173e+01 -1.778400e+00 -1.952132e+01      -5.150051e+00
# 25%   -4.100660e-01 -4.606309e-01 -1.672585e-01      -2.202220e-01
# 50%   -2.295898e-01 -2.606617e-01 -2.923025e-02      -6.280477e-02
# 75%    4.514490e-02  5.180285e-02  0.000000e+00       4.469501e-02
# max    3.599493e+01  9.045959e+00  4.408522e+01       3.700489e+01

# %% [markdown]
# decile portfolio

# %%
fig, axes = plt.subplots(7, 2, figsize=(12, 14))
for idx, feature in enumerate(features):
    ret2 = holdings_stk.groupby('date').apply(get_long_only_returns, signal_col=f"{feature}_zscore", perc=0.2, ret='future_ret').cumsum().to_frame().rename(columns= {0: f"{feature}_zscore"})
    ret2.plot(ax = axes[idx][0], grid = True, title=f"{feature}: long only return")
    ret2 = holdings_stk.groupby('date').apply(get_long_short_returns, signal_col=f"{feature}_zscore", perc=0.2, ret='future_ret').cumsum().to_frame().rename(columns= {0: f"{feature}_zscore"})
    ret2.plot(ax = axes[idx][1], grid = True, title=f"{feature}: long short return")
plt.tight_layout()

# %%
stats_long_only = []
stats_long_short = []

for feature in features:
    ret2 = holdings_stk.groupby('date').apply(get_long_only_returns, signal_col=f"{feature}_zscore", perc=0.2, ret='future_ret').to_frame().rename(columns= {0: f"{feature}_zscore"}).dropna()
    stats_long_only.append(backtest(ret2, feature))
    ret2 = holdings_stk.groupby('date').apply(get_long_short_returns, signal_col=f"{feature}_zscore", perc=0.2, ret='future_ret').to_frame().rename(columns= {0: f"{feature}_zscore"}).dropna()
    stats_long_short.append(backtest(ret2, feature))
    
perf = pd.concat(stats_long_short).loc[['weight_zscore', 'weight_diff_zscore', 'value_chg_zscore', 'mgrno_cnt_ratio_chg_zscore']].T
perf.columns = ['weight', 'weight_diff', 'value_chg', 'mgrno_cnt_ratio_chg']
perf
# Out:
#                    weight weight_diff   value_chg mgrno_cnt_ratio_chg
# start_date     2015-06-30  2015-09-30  2015-09-30          2015-09-30
# end_date       2022-06-30  2022-06-30  2022-06-30          2022-06-30
# n_quarter              29          28          28                  28
# n_pos_quarter          21          20          16                  16
# ret_annual       0.009478    0.006242    0.005575            0.004111
# std_annual       0.009267     0.00672     0.01015            0.008828
# shape            1.022709    0.928787    0.549328            0.465716
# mdd              0.007139    0.007993    0.013778             0.01211

# %% [markdown]
# ## visualization

# %%
# choose the stock that we care about
stk_focus = ["MICROSOFT CORP", "UNITED HEALTHCARE CORP", 'COSTCO WHOLESALE CORP']
permno_focus = [10107, 87055, 92655]
holdings_stk_focus = holdings_stk[holdings_stk.index.get_level_values(1).isin(permno_focus)].reset_index().set_index(['permno', 'date']).sort_index()

# change datetime index to date
holdings_stk_focus = holdings_stk_focus.reset_index()
holdings_stk_focus['date'] = holdings_stk_focus['date'].dt.date
holdings_stk_focus = holdings_stk_focus.set_index(['permno', 'date'])

# %%
holdings_stk_focus['ret'].unstack().T.plot.bar(figsize = (10, 3), grid=True, title = 'quarterly stock return', width=0.8);

# %% [markdown]
# ### weight

# %%
holdings_stk_focus['weight'].unstack().T.plot.bar(figsize = (10, 3), grid=True, title = 'average stock weight in the portfolio across institutions', width=0.8);

# %%
holdings_stk['weight'].clip(0, holdings_stk['weight'].quantile(0.99)).hist()
# Out:
# <Axes: >

# %% [markdown]
# ### weight_diff

# %%
holdings_stk_focus['weight_diff'].unstack().T.plot.bar(figsize = (10, 3), grid=True, title = 'average delta stock weight in the portfolio across institutions', width=0.8);

# %%
holdings_stk['weight_diff'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### buysale count

# %%
holdings_stk_focus['buysale'].unstack().T.plot.bar(figsize = (10, 3), grid=True, title = 'average buy sale counts across institutions', width=0.8);

# %%
holdings_stk['buysale'].clip(holdings_stk['buysale'].quantile(0.01), holdings_stk['buysale'].quantile(0.99)).hist()
# Out:
# <Axes: >

# %% [markdown]
# ### mgrno_cnt_ratio_chg

# %%
holdings_stk_focus['mgrno_cnt_ratio_chg'].unstack().T.plot.bar(figsize = (10, 3), grid=True, title = 'percentage of institutions holding the stock', width=0.8);

# %%
holdings_stk['mgrno_cnt_ratio_chg'].clip(holdings_stk['mgrno_cnt_ratio_chg'].quantile(0.01), holdings_stk['mgrno_cnt_ratio_chg'].quantile(0.99)).hist()
# Out:
# <Axes: >

# %% [markdown]
# ### value change

# %%
holdings_stk_focus['total_value'].unstack().T.plot.bar(figsize = (10, 3), grid=True, title = 'total stock holdings in dollar value across all institutions', width=0.8);

# %%
holdings_stk_focus['value_chg'].unstack().T.plot.bar(figsize = (10, 3), grid=True, title = 'change of stock holdings in dollar value across all institutions', width=0.8);

# %%
holdings_stk['value_chg'].clip(holdings_stk['value_chg'].quantile(0.01), holdings_stk['value_chg'].quantile(0.99)).hist()
# Out:
# <Axes: >

# %% [markdown]
# # Factor research

# %%
pv_file_path = '../data/price_vol_gics_all.parquet.gzip'
pv_data = pd.read_parquet(pv_file_path)

factor_file_path = '../data/factor_all.parquet.gzip'
factor_data = pd.read_parquet(factor_file_path)

signal_df = holdings_stk.reset_index().merge(factor_data, on=['date', 'permno'], how='left')
signal_df.dropna(inplace=True)

# %%
from function_lib import *
import warnings
warnings.filterwarnings("ignore")
plt.rc('figure', figsize=(10, 8))
plt.rcParams['font.size'] = 12
plt.rcParams['axes.titlesize'] = 12
plt.rcParams['axes.labelsize'] = 12
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_rows', 30)
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df_to_parquet(signal_df, 'signal_df')

# %%
signal_cols = ['weight', 'weight_diff', 'value_chg', 'mgrno_cnt_ratio_chg']
#signal_cols = 'value_chg'

"""
rvolhl_21d, The high-low return volatility (rvolhl_21d)
betadown_252d Downside beta (betadown_252d)
'ivol_ff3_21d', 'iskew_ff3_21d'. Idiosyncratic volatility & skewness from the Fama-French 3-factor model 
"""

risk_factors = ['dolvol', 'div12m_me', 'ret_1_0', 'ret_6_1', 'ret_12_1', 'ret_60_12',
              'at_gr1', 'ebit_sale', 'ebit_bev', 'sale_bev', 'niq_be', 'niq_su', 'ni_ar1', 'beta_60m', 
              'ami_126d', 'betadown_252d', 'rvolhl_21d'
]
ret_col = 'future_ret'
c.DATE = 'date'
c.SEC_ID = 'permno'
c.FREQUENCY = 'Q'

def prepare_signal(df, risk_factors, factors, group_cols = [c.SEC_ID]):
    """
    Normalize signals; risk_factors and factors are lists
    """
    security_df = df.copy()
    security_df.dropna(subset=risk_factors + factors, inplace=True)
    security_df.sort_values(by=c.DATE, inplace=True)
    security_df = get_z_scores(security_df, factors, suffix='_z')
    
    for signal in factors:
        security_df = orthogonalize_signals(security_df, [signal], risk_factors, by=c.DATE, suffix='_Resid')
    
    z_scored_list = [z for z in security_df.columns if z.endswith('_z') or z.endswith('_Resid')]
    return security_df, z_scored_list

signal_df = read_cache('signal_df')
signal_df, z_scored_y = prepare_signal(signal_df, risk_factors=risk_factors, factors=[ret_col])
signal_df, z_scored_features = prepare_signal(signal_df, risk_factors=risk_factors, factors=signal_cols)

df_to_parquet(signal_df, 'factor_neutralized_df')

signal_df.rename(columns={f'{ret_col}_Resid': 'AlphaReturn', f'{ret_col}_z': 'ExMktReturn',
                          'ivol_ff3_21d': 'InvSpecRisk'}, inplace=True)
# trade_df = signal_df.copy()  # can add other filters
signal_df.dropna(inplace=True)

# return_cols = ['ExMktReturn', 'AlphaReturn']
for signal in signal_cols:
    # z-scored signal backtest for residualized return
    # factor portfolio using WLS, with InvSpecRisk as the weight
    result_df = run_backtest(signal_df, signal_col=signal, return_col=['AlphaReturn'], lags=[0, 1, 2, 3, 4, 5])
# Out:
# <style type="text/css">
# #T_145f1 th {
#   width: 100px;
# }
# #T_145f1  td {
#   width: 100px;
# }
# #T_145f1 th {
#   width: auto;
# }
# #T_145f1  td {
#   width: auto;
# }
# #T_145f1_row0_col0, #T_145f1_row0_col2, #T_145f1_row0_col4, #T_145f1_row0_col6, #T_145f1_row1_col2, #T_145f1_row1_col4, #T_145f1_row1_col6, #T_145f1_row2_col2, #T_145f1_row2_col4, #T_145f1_row2_col6, #T_145f1_row3_col0, #T_145f1_row3_col2, #T_145f1_row3_col4, #T_145f1_row3_col6, #T_145f1_row4_col2, #T_145f1_row4_col4, #T_145f1_row4_col6, #T_145f1_row5_col2, #T_145f1_row5_col4, #T_145f1_row5_col6 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_145f1_row0_col1, #T_145f1_row0_col5, #T_145f1_row3_col5, #T_145f1_row4_col5 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_145f1_row0_col3 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_145f1_row0_col7, #T_145f1_row1_col7, #T_145f1_row2_col7, #T_145f1_row3_col7, #T_145f1_row4_col7, #T_145f1_row5_col7 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_145f1_row0_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_145f1_row1_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_145f1_row1_col1, #T_145f1_row2_col5, #T_145f1_row4_col0, #T_145f1_row5_col1 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_145f1_row1_col3, #T_145f1_row3_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_145f1_row1_col5 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_145f1_row1_col8 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_145f1_row2_col0 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_145f1_row2_col1, #T_145f1_row3_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_145f1_row2_col3, #T_145f1_row4_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_145f1_row2_col8 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_145f1_row3_col8 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_145f1_row4_col1 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_145f1_row4_col8 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_145f1_row5_col0, #T_145f1_row5_col5 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_145f1_row5_col3 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_145f1_row5_col8 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_145f1">
#   <caption>weight backtest</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_145f1_level0_col0" class="col_heading level0 col0" >Ann Ret%</th>
#       <th id="T_145f1_level0_col1" class="col_heading level0 col1" >Ann Vol%</th>
#       <th id="T_145f1_level0_col2" class="col_heading level0 col2" >Sharpe</th>
#       <th id="T_145f1_level0_col3" class="col_heading level0 col3" >Max DD%</th>
#       <th id="T_145f1_level0_col4" class="col_heading level0 col4" >T Stat</th>
#       <th id="T_145f1_level0_col5" class="col_heading level0 col5" >#|T|>2</th>
#       <th id="T_145f1_level0_col6" class="col_heading level0 col6" >Mean R^2%</th>
#       <th id="T_145f1_level0_col7" class="col_heading level0 col7" >Max R^2%</th>
#       <th id="T_145f1_level0_col8" class="col_heading level0 col8" >Mean Nobs</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ReturnType</th>
#       <th class="index_name level1" >lag</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_145f1_level0_row0" class="row_heading level0 row0" rowspan="6">AlphaReturn</th>
#       <th id="T_145f1_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_145f1_row0_col0" class="data row0 col0" >-6.11</td>
#       <td id="T_145f1_row0_col1" class="data row0 col1" >38.47</td>
#       <td id="T_145f1_row0_col2" class="data row0 col2" >-0.16</td>
#       <td id="T_145f1_row0_col3" class="data row0 col3" >-66.79</td>
#       <td id="T_145f1_row0_col4" class="data row0 col4" >-0.16</td>
#       <td id="T_145f1_row0_col5" class="data row0 col5" >42.11</td>
#       <td id="T_145f1_row0_col6" class="data row0 col6" >0.51</td>
#       <td id="T_145f1_row0_col7" class="data row0 col7" >2.29</td>
#       <td id="T_145f1_row0_col8" class="data row0 col8" >1346</td>
#     </tr>
#     <tr>
#       <th id="T_145f1_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_145f1_row1_col0" class="data row1 col0" >-17.80</td>
#       <td id="T_145f1_row1_col1" class="data row1 col1" >47.57</td>
#       <td id="T_145f1_row1_col2" class="data row1 col2" >-0.37</td>
#       <td id="T_145f1_row1_col3" class="data row1 col3" >-77.51</td>
#       <td id="T_145f1_row1_col4" class="data row1 col4" >-0.37</td>
#       <td id="T_145f1_row1_col5" class="data row1 col5" >55.56</td>
#       <td id="T_145f1_row1_col6" class="data row1 col6" >0.52</td>
#       <td id="T_145f1_row1_col7" class="data row1 col7" >2.56</td>
#       <td id="T_145f1_row1_col8" class="data row1 col8" >1331</td>
#     </tr>
#     <tr>
#       <th id="T_145f1_level1_row2" class="row_heading level1 row2" >2</th>
#       <td id="T_145f1_row2_col0" class="data row2 col0" >13.12</td>
#       <td id="T_145f1_row2_col1" class="data row2 col1" >59.96</td>
#       <td id="T_145f1_row2_col2" class="data row2 col2" >0.22</td>
#       <td id="T_145f1_row2_col3" class="data row2 col3" >-45.12</td>
#       <td id="T_145f1_row2_col4" class="data row2 col4" >0.22</td>
#       <td id="T_145f1_row2_col5" class="data row2 col5" >47.06</td>
#       <td id="T_145f1_row2_col6" class="data row2 col6" >0.75</td>
#       <td id="T_145f1_row2_col7" class="data row2 col7" >2.80</td>
#       <td id="T_145f1_row2_col8" class="data row2 col8" >1316</td>
#     </tr>
#     <tr>
#       <th id="T_145f1_level1_row3" class="row_heading level1 row3" >3</th>
#       <td id="T_145f1_row3_col0" class="data row3 col0" >1.01</td>
#       <td id="T_145f1_row3_col1" class="data row3 col1" >61.23</td>
#       <td id="T_145f1_row3_col2" class="data row3 col2" >0.02</td>
#       <td id="T_145f1_row3_col3" class="data row3 col3" >-81.44</td>
#       <td id="T_145f1_row3_col4" class="data row3 col4" >0.02</td>
#       <td id="T_145f1_row3_col5" class="data row3 col5" >37.50</td>
#       <td id="T_145f1_row3_col6" class="data row3 col6" >0.60</td>
#       <td id="T_145f1_row3_col7" class="data row3 col7" >3.50</td>
#       <td id="T_145f1_row3_col8" class="data row3 col8" >1301</td>
#     </tr>
#     <tr>
#       <th id="T_145f1_level1_row4" class="row_heading level1 row4" >4</th>
#       <td id="T_145f1_row4_col0" class="data row4 col0" >49.95</td>
#       <td id="T_145f1_row4_col1" class="data row4 col1" >71.21</td>
#       <td id="T_145f1_row4_col2" class="data row4 col2" >0.70</td>
#       <td id="T_145f1_row4_col3" class="data row4 col3" >-46.36</td>
#       <td id="T_145f1_row4_col4" class="data row4 col4" >0.70</td>
#       <td id="T_145f1_row4_col5" class="data row4 col5" >40.00</td>
#       <td id="T_145f1_row4_col6" class="data row4 col6" >0.93</td>
#       <td id="T_145f1_row4_col7" class="data row4 col7" >7.68</td>
#       <td id="T_145f1_row4_col8" class="data row4 col8" >1285</td>
#     </tr>
#     <tr>
#       <th id="T_145f1_level1_row5" class="row_heading level1 row5" >5</th>
#       <td id="T_145f1_row5_col0" class="data row5 col0" >24.71</td>
#       <td id="T_145f1_row5_col1" class="data row5 col1" >48.80</td>
#       <td id="T_145f1_row5_col2" class="data row5 col2" >0.51</td>
#       <td id="T_145f1_row5_col3" class="data row5 col3" >-49.81</td>
#       <td id="T_145f1_row5_col4" class="data row5 col4" >0.51</td>
#       <td id="T_145f1_row5_col5" class="data row5 col5" >28.57</td>
#       <td id="T_145f1_row5_col6" class="data row5 col6" >0.44</td>
#       <td id="T_145f1_row5_col7" class="data row5 col7" >2.21</td>
#       <td id="T_145f1_row5_col8" class="data row5 col8" >1269</td>
#     </tr>
#   </tbody>
# </table>
# correlation decay RunTime: 0.0252 seconds
# <style type="text/css">
# #T_d1341 th {
#   width: 100px;
# }
# #T_d1341  td {
#   width: 100px;
# }
# #T_d1341 th {
#   width: auto;
# }
# #T_d1341  td {
#   width: auto;
# }
# #T_d1341_row0_col0 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_d1341_row0_col1, #T_d1341_row2_col5 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_d1341_row0_col2, #T_d1341_row0_col4, #T_d1341_row0_col6, #T_d1341_row0_col7, #T_d1341_row1_col2, #T_d1341_row1_col4, #T_d1341_row1_col6, #T_d1341_row1_col7, #T_d1341_row2_col0, #T_d1341_row2_col2, #T_d1341_row2_col4, #T_d1341_row2_col6, #T_d1341_row2_col7, #T_d1341_row3_col2, #T_d1341_row3_col4, #T_d1341_row3_col6, #T_d1341_row3_col7, #T_d1341_row4_col2, #T_d1341_row4_col4, #T_d1341_row4_col6, #T_d1341_row5_col0, #T_d1341_row5_col2, #T_d1341_row5_col4, #T_d1341_row5_col6, #T_d1341_row5_col7 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_d1341_row0_col3, #T_d1341_row1_col3, #T_d1341_row2_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_d1341_row0_col5, #T_d1341_row3_col0, #T_d1341_row3_col5 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_d1341_row0_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d1341_row1_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_d1341_row1_col1 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_d1341_row1_col5 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_d1341_row1_col8 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_d1341_row2_col1, #T_d1341_row3_col1 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_d1341_row2_col8 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_d1341_row3_col3 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_d1341_row3_col8 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_d1341_row4_col0 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_d1341_row4_col1 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_d1341_row4_col3 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_d1341_row4_col5 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_d1341_row4_col7 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_d1341_row4_col8 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_d1341_row5_col1 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_d1341_row5_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_d1341_row5_col5 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_d1341_row5_col8 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d1341">
#   <caption>weight_diff backtest</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1341_level0_col0" class="col_heading level0 col0" >Ann Ret%</th>
#       <th id="T_d1341_level0_col1" class="col_heading level0 col1" >Ann Vol%</th>
#       <th id="T_d1341_level0_col2" class="col_heading level0 col2" >Sharpe</th>
#       <th id="T_d1341_level0_col3" class="col_heading level0 col3" >Max DD%</th>
#       <th id="T_d1341_level0_col4" class="col_heading level0 col4" >T Stat</th>
#       <th id="T_d1341_level0_col5" class="col_heading level0 col5" >#|T|>2</th>
#       <th id="T_d1341_level0_col6" class="col_heading level0 col6" >Mean R^2%</th>
#       <th id="T_d1341_level0_col7" class="col_heading level0 col7" >Max R^2%</th>
#       <th id="T_d1341_level0_col8" class="col_heading level0 col8" >Mean Nobs</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ReturnType</th>
#       <th class="index_name level1" >lag</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1341_level0_row0" class="row_heading level0 row0" rowspan="6">AlphaReturn</th>
#       <th id="T_d1341_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_d1341_row0_col0" class="data row0 col0" >-27.68</td>
#       <td id="T_d1341_row0_col1" class="data row0 col1" >64.84</td>
#       <td id="T_d1341_row0_col2" class="data row0 col2" >-0.43</td>
#       <td id="T_d1341_row0_col3" class="data row0 col3" >-94.77</td>
#       <td id="T_d1341_row0_col4" class="data row0 col4" >-0.43</td>
#       <td id="T_d1341_row0_col5" class="data row0 col5" >36.84</td>
#       <td id="T_d1341_row0_col6" class="data row0 col6" >0.45</td>
#       <td id="T_d1341_row0_col7" class="data row0 col7" >3.99</td>
#       <td id="T_d1341_row0_col8" class="data row0 col8" >1346</td>
#     </tr>
#     <tr>
#       <th id="T_d1341_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_d1341_row1_col0" class="data row1 col0" >-53.96</td>
#       <td id="T_d1341_row1_col1" class="data row1 col1" >87.96</td>
#       <td id="T_d1341_row1_col2" class="data row1 col2" >-0.61</td>
#       <td id="T_d1341_row1_col3" class="data row1 col3" >-99.69</td>
#       <td id="T_d1341_row1_col4" class="data row1 col4" >-0.61</td>
#       <td id="T_d1341_row1_col5" class="data row1 col5" >44.44</td>
#       <td id="T_d1341_row1_col6" class="data row1 col6" >0.41</td>
#       <td id="T_d1341_row1_col7" class="data row1 col7" >1.78</td>
#       <td id="T_d1341_row1_col8" class="data row1 col8" >1331</td>
#     </tr>
#     <tr>
#       <th id="T_d1341_level1_row2" class="row_heading level1 row2" >2</th>
#       <td id="T_d1341_row2_col0" class="data row2 col0" >-1.09</td>
#       <td id="T_d1341_row2_col1" class="data row2 col1" >101.00</td>
#       <td id="T_d1341_row2_col2" class="data row2 col2" >-0.01</td>
#       <td id="T_d1341_row2_col3" class="data row2 col3" >-95.11</td>
#       <td id="T_d1341_row2_col4" class="data row2 col4" >-0.01</td>
#       <td id="T_d1341_row2_col5" class="data row2 col5" >64.71</td>
#       <td id="T_d1341_row2_col6" class="data row2 col6" >0.51</td>
#       <td id="T_d1341_row2_col7" class="data row2 col7" >1.33</td>
#       <td id="T_d1341_row2_col8" class="data row2 col8" >1316</td>
#     </tr>
#     <tr>
#       <th id="T_d1341_level1_row3" class="row_heading level1 row3" >3</th>
#       <td id="T_d1341_row3_col0" class="data row3 col0" >37.83</td>
#       <td id="T_d1341_row3_col1" class="data row3 col1" >104.92</td>
#       <td id="T_d1341_row3_col2" class="data row3 col2" >0.36</td>
#       <td id="T_d1341_row3_col3" class="data row3 col3" >-72.45</td>
#       <td id="T_d1341_row3_col4" class="data row3 col4" >0.36</td>
#       <td id="T_d1341_row3_col5" class="data row3 col5" >37.50</td>
#       <td id="T_d1341_row3_col6" class="data row3 col6" >0.48</td>
#       <td id="T_d1341_row3_col7" class="data row3 col7" >3.24</td>
#       <td id="T_d1341_row3_col8" class="data row3 col8" >1301</td>
#     </tr>
#     <tr>
#       <th id="T_d1341_level1_row4" class="row_heading level1 row4" >4</th>
#       <td id="T_d1341_row4_col0" class="data row4 col0" >82.38</td>
#       <td id="T_d1341_row4_col1" class="data row4 col1" >198.87</td>
#       <td id="T_d1341_row4_col2" class="data row4 col2" >0.41</td>
#       <td id="T_d1341_row4_col3" class="data row4 col3" >-91.26</td>
#       <td id="T_d1341_row4_col4" class="data row4 col4" >0.41</td>
#       <td id="T_d1341_row4_col5" class="data row4 col5" >40.00</td>
#       <td id="T_d1341_row4_col6" class="data row4 col6" >1.67</td>
#       <td id="T_d1341_row4_col7" class="data row4 col7" >19.08</td>
#       <td id="T_d1341_row4_col8" class="data row4 col8" >1285</td>
#     </tr>
#     <tr>
#       <th id="T_d1341_level1_row5" class="row_heading level1 row5" >5</th>
#       <td id="T_d1341_row5_col0" class="data row5 col0" >8.38</td>
#       <td id="T_d1341_row5_col1" class="data row5 col1" >134.93</td>
#       <td id="T_d1341_row5_col2" class="data row5 col2" >0.06</td>
#       <td id="T_d1341_row5_col3" class="data row5 col3" >-122.82</td>
#       <td id="T_d1341_row5_col4" class="data row5 col4" >0.06</td>
#       <td id="T_d1341_row5_col5" class="data row5 col5" >50.00</td>
#       <td id="T_d1341_row5
# correlation decay RunTime: 0.0258 seconds
# <style type="text/css">
# #T_b18bf th {
#   width: 100px;
# }
# #T_b18bf  td {
#   width: 100px;
# }
# #T_b18bf th {
#   width: auto;
# }
# #T_b18bf  td {
#   width: auto;
# }
# #T_b18bf_row0_col0, #T_b18bf_row0_col1, #T_b18bf_row0_col2, #T_b18bf_row0_col3, #T_b18bf_row0_col4, #T_b18bf_row0_col6, #T_b18bf_row1_col0, #T_b18bf_row1_col1, #T_b18bf_row1_col2, #T_b18bf_row1_col3, #T_b18bf_row1_col4, #T_b18bf_row1_col6, #T_b18bf_row1_col7, #T_b18bf_row2_col0, #T_b18bf_row2_col1, #T_b18bf_row2_col2, #T_b18bf_row2_col3, #T_b18bf_row2_col4, #T_b18bf_row2_col6, #T_b18bf_row3_col0, #T_b18bf_row3_col1, #T_b18bf_row3_col2, #T_b18bf_row3_col3, #T_b18bf_row3_col4, #T_b18bf_row3_col6, #T_b18bf_row4_col0, #T_b18bf_row4_col1, #T_b18bf_row4_col2, #T_b18bf_row4_col3, #T_b18bf_row4_col4, #T_b18bf_row4_col6, #T_b18bf_row5_col0, #T_b18bf_row5_col1, #T_b18bf_row5_col2, #T_b18bf_row5_col3, #T_b18bf_row5_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_b18bf_row0_col5, #T_b18bf_row1_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_b18bf_row0_col7, #T_b18bf_row2_col7, #T_b18bf_row3_col7, #T_b18bf_row4_col7, #T_b18bf_row5_col6 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_b18bf_row0_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_b18bf_row1_col8 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_b18bf_row2_col5, #T_b18bf_row4_col5 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_b18bf_row2_col8 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_b18bf_row3_col5 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_b18bf_row3_col8 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_b18bf_row4_col8 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_b18bf_row5_col5 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_b18bf_row5_col7 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_b18bf_row5_col8 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b18bf">
#   <caption>value_chg backtest</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b18bf_level0_col0" class="col_heading level0 col0" >Ann Ret%</th>
#       <th id="T_b18bf_level0_col1" class="col_heading level0 col1" >Ann Vol%</th>
#       <th id="T_b18bf_level0_col2" class="col_heading level0 col2" >Sharpe</th>
#       <th id="T_b18bf_level0_col3" class="col_heading level0 col3" >Max DD%</th>
#       <th id="T_b18bf_level0_col4" class="col_heading level0 col4" >T Stat</th>
#       <th id="T_b18bf_level0_col5" class="col_heading level0 col5" >#|T|>2</th>
#       <th id="T_b18bf_level0_col6" class="col_heading level0 col6" >Mean R^2%</th>
#       <th id="T_b18bf_level0_col7" class="col_heading level0 col7" >Max R^2%</th>
#       <th id="T_b18bf_level0_col8" class="col_heading level0 col8" >Mean Nobs</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ReturnType</th>
#       <th class="index_name level1" >lag</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b18bf_level0_row0" class="row_heading level0 row0" rowspan="6">AlphaReturn</th>
#       <th id="T_b18bf_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_b18bf_row0_col0" class="data row0 col0" >-0.54</td>
#       <td id="T_b18bf_row0_col1" class="data row0 col1" >0.93</td>
#       <td id="T_b18bf_row0_col2" class="data row0 col2" >-0.58</td>
#       <td id="T_b18bf_row0_col3" class="data row0 col3" >-2.57</td>
#       <td id="T_b18bf_row0_col4" class="data row0 col4" >-0.58</td>
#       <td id="T_b18bf_row0_col5" class="data row0 col5" >21.05</td>
#       <td id="T_b18bf_row0_col6" class="data row0 col6" >0.48</td>
#       <td id="T_b18bf_row0_col7" class="data row0 col7" >5.87</td>
#       <td id="T_b18bf_row0_col8" class="data row0 col8" >1346</td>
#     </tr>
#     <tr>
#       <th id="T_b18bf_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_b18bf_row1_col0" class="data row1 col0" >-0.48</td>
#       <td id="T_b18bf_row1_col1" class="data row1 col1" >0.78</td>
#       <td id="T_b18bf_row1_col2" class="data row1 col2" >-0.61</td>
#       <td id="T_b18bf_row1_col3" class="data row1 col3" >-2.56</td>
#       <td id="T_b18bf_row1_col4" class="data row1 col4" >-0.61</td>
#       <td id="T_b18bf_row1_col5" class="data row1 col5" >22.22</td>
#       <td id="T_b18bf_row1_col6" class="data row1 col6" >0.30</td>
#       <td id="T_b18bf_row1_col7" class="data row1 col7" >1.51</td>
#       <td id="T_b18bf_row1_col8" class="data row1 col8" >1331</td>
#     </tr>
#     <tr>
#       <th id="T_b18bf_level1_row2" class="row_heading level1 row2" >2</th>
#       <td id="T_b18bf_row2_col0" class="data row2 col0" >0.22</td>
#       <td id="T_b18bf_row2_col1" class="data row2 col1" >1.19</td>
#       <td id="T_b18bf_row2_col2" class="data row2 col2" >0.18</td>
#       <td id="T_b18bf_row2_col3" class="data row2 col3" >-1.44</td>
#       <td id="T_b18bf_row2_col4" class="data row2 col4" >0.18</td>
#       <td id="T_b18bf_row2_col5" class="data row2 col5" >41.18</td>
#       <td id="T_b18bf_row2_col6" class="data row2 col6" >0.54</td>
#       <td id="T_b18bf_row2_col7" class="data row2 col7" >3.11</td>
#       <td id="T_b18bf_row2_col8" class="data row2 col8" >1316</td>
#     </tr>
#     <tr>
#       <th id="T_b18bf_level1_row3" class="row_heading level1 row3" >3</th>
#       <td id="T_b18bf_row3_col0" class="data row3 col0" >0.55</td>
#       <td id="T_b18bf_row3_col1" class="data row3 col1" >1.22</td>
#       <td id="T_b18bf_row3_col2" class="data row3 col2" >0.45</td>
#       <td id="T_b18bf_row3_col3" class="data row3 col3" >-0.89</td>
#       <td id="T_b18bf_row3_col4" class="data row3 col4" >0.45</td>
#       <td id="T_b18bf_row3_col5" class="data row3 col5" >25.00</td>
#       <td id="T_b18bf_row3_col6" class="data row3 col6" >0.38</td>
#       <td id="T_b18bf_row3_col7" class="data row3 col7" >3.75</td>
#       <td id="T_b18bf_row3_col8" class="data row3 col8" >1301</td>
#     </tr>
#     <tr>
#       <th id="T_b18bf_level1_row4" class="row_heading level1 row4" >4</th>
#       <td id="T_b18bf_row4_col0" class="data row4 col0" >-0.20</td>
#       <td id="T_b18bf_row4_col1" class="data row4 col1" >0.79</td>
#       <td id="T_b18bf_row4_col2" class="data row4 col2" >-0.26</td>
#       <td id="T_b18bf_row4_col3" class="data row4 col3" >-1.33</td>
#       <td id="T_b18bf_row4_col4" class="data row4 col4" >-0.26</td>
#       <td id="T_b18bf_row4_col5" class="data row4 col5" >40.00</td>
#       <td id="T_b18bf_row4_col6" class="data row4 col6" >0.62</td>
#       <td id="T_b18bf_row4_col7" class="data row4 col7" >5.28</td>
#       <td id="T_b18bf_row4_col8" class="data row4 col8" >1285</td>
#     </tr>
#     <tr>
#       <th id="T_b18bf_level1_row5" class="row_heading level1 row5" >5</th>
#       <td id="T_b18bf_row5_col0" class="data row5 col0" >0.30</td>
#       <td id="T_b18bf_row5_col1" class="data row5 col1" >1.14</td>
#       <td id="T_b18bf_row5_col2" class="data row5 col2" >0.26</td>
#       <td id="T_b18bf_row5_col3" class="data row5 col3" >-1.40</td>
#       <td id="T_b18bf_row5_col4" class="data row5 col4" >0.26</td>
#       <td id="T_b18bf_row5_col5" class="data row5 col5" >50.00</td>
#       <td id="T_b18bf_row5_col6" class="data row5 col6" >4.92</td>
#       <td id="T_b18bf_row5_col7" class="data row5 col7" >52.57</td>
#       <td id="T_b18bf_row5_col8" class="data row5 col8" >1269</td>
#     </tr>
#   </tbody>
# </table>
# correlation decay RunTime: 0.0275 seconds
# <style type="text/css">
# #T_13bf7 th {
#   width: 100px;
# }
# #T_13bf7  td {
#   width: 100px;
# }
# #T_13bf7 th {
#   width: auto;
# }
# #T_13bf7  td {
#   width: auto;
# }
# #T_13bf7_row0_col0, #T_13bf7_row0_col1, #T_13bf7_row0_col2, #T_13bf7_row0_col3, #T_13bf7_row0_col4, #T_13bf7_row0_col6, #T_13bf7_row0_col7, #T_13bf7_row1_col0, #T_13bf7_row1_col2, #T_13bf7_row1_col4, #T_13bf7_row1_col6, #T_13bf7_row2_col0, #T_13bf7_row2_col1, #T_13bf7_row2_col2, #T_13bf7_row2_col3, #T_13bf7_row2_col4, #T_13bf7_row2_col6, #T_13bf7_row3_col0, #T_13bf7_row3_col2, #T_13bf7_row3_col4, #T_13bf7_row3_col6, #T_13bf7_row4_col0, #T_13bf7_row4_col1, #T_13bf7_row4_col2, #T_13bf7_row4_col3, #T_13bf7_row4_col4, #T_13bf7_row4_col6, #T_13bf7_row5_col0, #T_13bf7_row5_col1, #T_13bf7_row5_col2, #T_13bf7_row5_col3, #T_13bf7_row5_col4, #T_13bf7_row5_col6 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_13bf7_row0_col5, #T_13bf7_row3_col5, #T_13bf7_row5_col5 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_13bf7_row0_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_13bf7_row1_col1, #T_13bf7_row1_col7, #T_13bf7_row2_col7, #T_13bf7_row3_col1, #T_13bf7_row3_col7, #T_13bf7_row4_col7 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_13bf7_row1_col3, #T_13bf7_row3_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_13bf7_row1_col5, #T_13bf7_row2_col5, #T_13bf7_row5_col7 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_13bf7_row1_col8 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_13bf7_row2_col8 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_13bf7_row3_col8 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_13bf7_row4_col5 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_13bf7_row4_col8 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_13bf7_row5_col8 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_13bf7">
#   <caption>mgrno_cnt_ratio_chg backtest</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13bf7_level0_col0" class="col_heading level0 col0" >Ann Ret%</th>
#       <th id="T_13bf7_level0_col1" class="col_heading level0 col1" >Ann Vol%</th>
#       <th id="T_13bf7_level0_col2" class="col_heading level0 col2" >Sharpe</th>
#       <th id="T_13bf7_level0_col3" class="col_heading level0 col3" >Max DD%</th>
#       <th id="T_13bf7_level0_col4" class="col_heading level0 col4" >T Stat</th>
#       <th id="T_13bf7_level0_col5" class="col_heading level0 col5" >#|T|>2</th>
#       <th id="T_13bf7_level0_col6" class="col_heading level0 col6" >Mean R^2%</th>
#       <th id="T_13bf7_level0_col7" class="col_heading level0 col7" >Max R^2%</th>
#       <th id="T_13bf7_level0_col8" class="col_heading level0 col8" >Mean Nobs</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ReturnType</th>
#       <th class="index_name level1" >lag</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13bf7_level0_row0" class="row_heading level0 row0" rowspan="6">AlphaReturn</th>
#       <th id="T_13bf7_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_13bf7_row0_col0" class="data row0 col0" >0.74</td>
#       <td id="T_13bf7_row0_col1" class="data row0 col1" >2.39</td>
#       <td id="T_13bf7_row0_col2" class="data row0 col2" >0.31</td>
#       <td id="T_13bf7_row0_col3" class="data row0 col3" >-2.69</td>
#       <td id="T_13bf7_row0_col4" class="data row0 col4" >0.31</td>
#       <td id="T_13bf7_row0_col5" class="data row0 col5" >26.32</td>
#       <td id="T_13bf7_row0_col6" class="data row0 col6" >0.27</td>
#       <td id="T_13bf7_row0_col7" class="data row0 col7" >1.20</td>
#       <td id="T_13bf7_row0_col8" class="data row0 col8" >1346</td>
#     </tr>
#     <tr>
#       <th id="T_13bf7_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_13bf7_row1_col0" class="data row1 col0" >-1.05</td>
#       <td id="T_13bf7_row1_col1" class="data row1 col1" >2.97</td>
#       <td id="T_13bf7_row1_col2" class="data row1 col2" >-0.35</td>
#       <td id="T_13bf7_row1_col3" class="data row1 col3" >-8.12</td>
#       <td id="T_13bf7_row1_col4" class="data row1 col4" >-0.35</td>
#       <td id="T_13bf7_row1_col5" class="data row1 col5" >16.67</td>
#       <td id="T_13bf7_row1_col6" class="data row1 col6" >0.36</td>
#       <td id="T_13bf7_row1_col7" class="data row1 col7" >3.92</td>
#       <td id="T_13bf7_row1_col8" class="data row1 col8" >1331</td>
#     </tr>
#     <tr>
#       <th id="T_13bf7_level1_row2" class="row_heading level1 row2" >2</th>
#       <td id="T_13bf7_row2_col0" class="data row2 col0" >1.78</td>
#       <td id="T_13bf7_row2_col1" class="data row2 col1" >2.40</td>
#       <td id="T_13bf7_row2_col2" class="data row2 col2" >0.74</td>
#       <td id="T_13bf7_row2_col3" class="data row2 col3" >-1.23</td>
#       <td id="T_13bf7_row2_col4" class="data row2 col4" >0.74</td>
#       <td id="T_13bf7_row2_col5" class="data row2 col5" >17.65</td>
#       <td id="T_13bf7_row2_col6" class="data row2 col6" >0.29</td>
#       <td id="T_13bf7_row2_col7" class="data row2 col7" >3.14</td>
#       <td id="T_13bf7_row2_col8" class="data row2 col8" >1316</td>
#     </tr>
#     <tr>
#       <th id="T_13bf7_level1_row3" class="row_heading level1 row3" >3</th>
#       <td id="T_13bf7_row3_col0" class="data row3 col0" >-1.02</td>
#       <td id="T_13bf7_row3_col1" class="data row3 col1" >2.73</td>
#       <td id="T_13bf7_row3_col2" class="data row3 col2" >-0.37</td>
#       <td id="T_13bf7_row3_col3" class="data row3 col3" >-7.14</td>
#       <td id="T_13bf7_row3_col4" class="data row3 col4" >-0.37</td>
#       <td id="T_13bf7_row3_col5" class="data row3 col5" >25.00</td>
#       <td id="T_13bf7_row3_col6" class="data row3 col6" >0.41</td>
#       <td id="T_13bf7_row3_col7" class="data row3 col7" >4.12</td>
#       <td id="T_13bf7_row3_col8" class="data row3 col8" >1301</td>
#     </tr>
#     <tr>
#       <th id="T_13bf7_level1_row4" class="row_heading level1 row4" >4</th>
#       <td id="T_13bf7_row4_col0" class="data row4 col0" >1.43</td>
#       <td id="T_13bf7_row4_col1" class="data row4 col1" >2.43</td>
#       <td id="T_13bf7_row4_col2" class="data row4 col2" >0.59</td>
#       <td id="T_13bf7_row4_col3" class="data row4 col3" >-2.36</td>
#       <td id="T_13bf7_row4_col4" class="data row4 col4" >0.59</td>
#       <td id="T_13bf7_row4_col5" class="data row4 col5" >40.00</td>
#       <td id="T_13bf7_row4_col6" class="data row4 col6" >0.50</td>
#       <td id="T_13bf7_row4_col7" class="data row4 col7" >3.64</td>
#       <td id="T_13bf7_row4_col8" class="data row4 col8" >1285</td>
#     </tr>
#     <tr>
#       <th id="T_13bf7_level1_row5" class="row_heading level1 row5" >5</th>
#       <td id="T_13bf7_row5_col0" class="data row5 col0" >1.26</td>
#       <td id="T_13bf7_row5_col1" class="data row5 col1" >1.89</td>
#       <td id="T_13bf7_row5_col2" class="data row5 col2" >0.66</td>
#       <td id="T_13bf7_row5_col3" class="data row5 col3" >-2.01</td>
#       <td id="T_13bf7_row5_col4" class="data row5 col4" >0.66</td>
#       <td id="T_13bf7_row5_col5" class="data row5 col5" >28.57</td>
#       <td id="T_13bf7_row5_col6" class="data row5 col6" >1.19</td>
#       <td id="T_13bf7_row5_col7" class="data row5 col7" >13.52</td>
#       <td id="T_13bf7_row5_col8" class="data row5 col8" >1269</td>
#     </tr>
#   </tbody>
# </table>
# correlation decay RunTime: 0.0303 seconds

# %%
# Factor regression using OLS. no weight
for signal in signal_cols:
    result_df = run_backtest(signal_df, signal_col=signal, return_col=['AlphaReturn'], lags=[0, 1, 2, 3, 4, 5], WLS_model=False)
# Out:
# <style type="text/css">
# #T_a5da2 th {
#   width: 100px;
# }
# #T_a5da2  td {
#   width: 100px;
# }
# #T_a5da2 th {
#   width: auto;
# }
# #T_a5da2  td {
#   width: auto;
# }
# #T_a5da2_row0_col0, #T_a5da2_row3_col0 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_a5da2_row0_col1, #T_a5da2_row0_col5, #T_a5da2_row1_col5, #T_a5da2_row3_col5, #T_a5da2_row4_col1, #T_a5da2_row4_col5 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_a5da2_row0_col2, #T_a5da2_row0_col4, #T_a5da2_row0_col6, #T_a5da2_row0_col7, #T_a5da2_row1_col0, #T_a5da2_row1_col2, #T_a5da2_row1_col4, #T_a5da2_row1_col6, #T_a5da2_row1_col7, #T_a5da2_row2_col2, #T_a5da2_row2_col4, #T_a5da2_row2_col6, #T_a5da2_row2_col7, #T_a5da2_row3_col2, #T_a5da2_row3_col4, #T_a5da2_row3_col6, #T_a5da2_row3_col7, #T_a5da2_row4_col2, #T_a5da2_row4_col4, #T_a5da2_row4_col6, #T_a5da2_row4_col7, #T_a5da2_row5_col2, #T_a5da2_row5_col4, #T_a5da2_row5_col6, #T_a5da2_row5_col7 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_a5da2_row0_col3, #T_a5da2_row4_col3, #T_a5da2_row5_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_a5da2_row0_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_a5da2_row1_col1, #T_a5da2_row5_col1 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_a5da2_row1_col3, #T_a5da2_row3_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_a5da2_row1_col8 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_a5da2_row2_col0, #T_a5da2_row4_col0, #T_a5da2_row5_col0, #T_a5da2_row5_col5 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_a5da2_row2_col1, #T_a5da2_row3_col1 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_a5da2_row2_col3 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_a5da2_row2_col5 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_a5da2_row2_col8 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_a5da2_row3_col8 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_a5da2_row4_col8 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_a5da2_row5_col8 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a5da2">
#   <caption>weight backtest</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5da2_level0_col0" class="col_heading level0 col0" >Ann Ret%</th>
#       <th id="T_a5da2_level0_col1" class="col_heading level0 col1" >Ann Vol%</th>
#       <th id="T_a5da2_level0_col2" class="col_heading level0 col2" >Sharpe</th>
#       <th id="T_a5da2_level0_col3" class="col_heading level0 col3" >Max DD%</th>
#       <th id="T_a5da2_level0_col4" class="col_heading level0 col4" >T Stat</th>
#       <th id="T_a5da2_level0_col5" class="col_heading level0 col5" >#|T|>2</th>
#       <th id="T_a5da2_level0_col6" class="col_heading level0 col6" >Mean R^2%</th>
#       <th id="T_a5da2_level0_col7" class="col_heading level0 col7" >Max R^2%</th>
#       <th id="T_a5da2_level0_col8" class="col_heading level0 col8" >Mean Nobs</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ReturnType</th>
#       <th class="index_name level1" >lag</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5da2_level0_row0" class="row_heading level0 row0" rowspan="6">AlphaReturn</th>
#       <th id="T_a5da2_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_a5da2_row0_col0" class="data row0 col0" >8.81</td>
#       <td id="T_a5da2_row0_col1" class="data row0 col1" >31.52</td>
#       <td id="T_a5da2_row0_col2" class="data row0 col2" >0.28</td>
#       <td id="T_a5da2_row0_col3" class="data row0 col3" >-26.49</td>
#       <td id="T_a5da2_row0_col4" class="data row0 col4" >0.28</td>
#       <td id="T_a5da2_row0_col5" class="data row0 col5" >31.58</td>
#       <td id="T_a5da2_row0_col6" class="data row0 col6" >0.32</td>
#       <td id="T_a5da2_row0_col7" class="data row0 col7" >1.40</td>
#       <td id="T_a5da2_row0_col8" class="data row0 col8" >1346</td>
#     </tr>
#     <tr>
#       <th id="T_a5da2_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_a5da2_row1_col0" class="data row1 col0" >0.59</td>
#       <td id="T_a5da2_row1_col1" class="data row1 col1" >38.04</td>
#       <td id="T_a5da2_row1_col2" class="data row1 col2" >0.02</td>
#       <td id="T_a5da2_row1_col3" class="data row1 col3" >-45.79</td>
#       <td id="T_a5da2_row1_col4" class="data row1 col4" >0.02</td>
#       <td id="T_a5da2_row1_col5" class="data row1 col5" >27.78</td>
#       <td id="T_a5da2_row1_col6" class="data row1 col6" >0.35</td>
#       <td id="T_a5da2_row1_col7" class="data row1 col7" >2.29</td>
#       <td id="T_a5da2_row1_col8" class="data row1 col8" >1331</td>
#     </tr>
#     <tr>
#       <th id="T_a5da2_level1_row2" class="row_heading level1 row2" >2</th>
#       <td id="T_a5da2_row2_col0" class="data row2 col0" >21.14</td>
#       <td id="T_a5da2_row2_col1" class="data row2 col1" >45.41</td>
#       <td id="T_a5da2_row2_col2" class="data row2 col2" >0.47</td>
#       <td id="T_a5da2_row2_col3" class="data row2 col3" >-36.25</td>
#       <td id="T_a5da2_row2_col4" class="data row2 col4" >0.47</td>
#       <td id="T_a5da2_row2_col5" class="data row2 col5" >47.06</td>
#       <td id="T_a5da2_row2_col6" class="data row2 col6" >0.51</td>
#       <td id="T_a5da2_row2_col7" class="data row2 col7" >2.71</td>
#       <td id="T_a5da2_row2_col8" class="data row2 col8" >1316</td>
#     </tr>
#     <tr>
#       <th id="T_a5da2_level1_row3" class="row_heading level1 row3" >3</th>
#       <td id="T_a5da2_row3_col0" class="data row3 col0" >10.50</td>
#       <td id="T_a5da2_row3_col1" class="data row3 col1" >41.48</td>
#       <td id="T_a5da2_row3_col2" class="data row3 col2" >0.25</td>
#       <td id="T_a5da2_row3_col3" class="data row3 col3" >-45.66</td>
#       <td id="T_a5da2_row3_col4" class="data row3 col4" >0.25</td>
#       <td id="T_a5da2_row3_col5" class="data row3 col5" >31.25</td>
#       <td id="T_a5da2_row3_col6" class="data row3 col6" >0.37</td>
#       <td id="T_a5da2_row3_col7" class="data row3 col7" >2.14</td>
#       <td id="T_a5da2_row3_col8" class="data row3 col8" >1301</td>
#     </tr>
#     <tr>
#       <th id="T_a5da2_level1_row4" class="row_heading level1 row4" >4</th>
#       <td id="T_a5da2_row4_col0" class="data row4 col0" >24.62</td>
#       <td id="T_a5da2_row4_col1" class="data row4 col1" >34.66</td>
#       <td id="T_a5da2_row4_col2" class="data row4 col2" >0.71</td>
#       <td id="T_a5da2_row4_col3" class="data row4 col3" >-21.63</td>
#       <td id="T_a5da2_row4_col4" class="data row4 col4" >0.71</td>
#       <td id="T_a5da2_row4_col5" class="data row4 col5" >33.33</td>
#       <td id="T_a5da2_row4_col6" class="data row4 col6" >0.33</td>
#       <td id="T_a5da2_row4_col7" class="data row4 col7" >2.16</td>
#       <td id="T_a5da2_row4_col8" class="data row4 col8" >1285</td>
#     </tr>
#     <tr>
#       <th id="T_a5da2_level1_row5" class="row_heading level1 row5" >5</th>
#       <td id="T_a5da2_row5_col0" class="data row5 col0" >21.48</td>
#       <td id="T_a5da2_row5_col1" class="data row5 col1" >36.94</td>
#       <td id="T_a5da2_row5_col2" class="data row5 col2" >0.58</td>
#       <td id="T_a5da2_row5_col3" class="data row5 col3" >-21.20</td>
#       <td id="T_a5da2_row5_col4" class="data row5 col4" >0.58</td>
#       <td id="T_a5da2_row5_col5" class="data row5 col5" >21.43</td>
#       <td id="T_a5da2_row5_col6" class="data row5 col6" >0.31</td>
#       <td id="T_a5da2_row5_col7" class="data row5 col7" >2.04</td>
#       <td id="T_a5da2_row5_col8" class="data row5 col8" >1269</td>
#     </tr>
#   </tbody>
# </table>
# correlation decay RunTime: 0.0255 seconds
# <style type="text/css">
# #T_f054f th {
#   width: 100px;
# }
# #T_f054f  td {
#   width: 100px;
# }
# #T_f054f th {
#   width: auto;
# }
# #T_f054f  td {
#   width: auto;
# }
# #T_f054f_row0_col0 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_f054f_row0_col1, #T_f054f_row3_col1, #T_f054f_row5_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_f054f_row0_col2, #T_f054f_row0_col4, #T_f054f_row0_col6, #T_f054f_row1_col2, #T_f054f_row1_col4, #T_f054f_row1_col6, #T_f054f_row2_col2, #T_f054f_row2_col4, #T_f054f_row2_col6, #T_f054f_row3_col2, #T_f054f_row3_col4, #T_f054f_row3_col6, #T_f054f_row4_col2, #T_f054f_row4_col4, #T_f054f_row4_col6, #T_f054f_row5_col2, #T_f054f_row5_col4, #T_f054f_row5_col6 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_f054f_row0_col3, #T_f054f_row2_col3, #T_f054f_row4_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_f054f_row0_col5, #T_f054f_row1_col5, #T_f054f_row2_col5, #T_f054f_row3_col5, #T_f054f_row4_col5 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_f054f_row0_col7, #T_f054f_row1_col7, #T_f054f_row2_col7, #T_f054f_row3_col7, #T_f054f_row4_col7, #T_f054f_row5_col7 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_f054f_row0_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_f054f_row1_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_f054f_row1_col1 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_f054f_row1_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_f054f_row1_col8 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_f054f_row2_col0, #T_f054f_row3_col0, #T_f054f_row4_col0 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_f054f_row2_col1 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_f054f_row2_col8 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_f054f_row3_col3 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_f054f_row3_col8 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_f054f_row4_col1 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_f054f_row4_col8 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_f054f_row5_col0 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_f054f_row5_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_f054f_row5_col5 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_f054f_row5_col8 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f054f">
#   <caption>weight_diff backtest</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f054f_level0_col0" class="col_heading level0 col0" >Ann Ret%</th>
#       <th id="T_f054f_level0_col1" class="col_heading level0 col1" >Ann Vol%</th>
#       <th id="T_f054f_level0_col2" class="col_heading level0 col2" >Sharpe</th>
#       <th id="T_f054f_level0_col3" class="col_heading level0 col3" >Max DD%</th>
#       <th id="T_f054f_level0_col4" class="col_heading level0 col4" >T Stat</th>
#       <th id="T_f054f_level0_col5" class="col_heading level0 col5" >#|T|>2</th>
#       <th id="T_f054f_level0_col6" class="col_heading level0 col6" >Mean R^2%</th>
#       <th id="T_f054f_level0_col7" class="col_heading level0 col7" >Max R^2%</th>
#       <th id="T_f054f_level0_col8" class="col_heading level0 col8" >Mean Nobs</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ReturnType</th>
#       <th class="index_name level1" >lag</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f054f_level0_row0" class="row_heading level0 row0" rowspan="6">AlphaReturn</th>
#       <th id="T_f054f_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_f054f_row0_col0" class="data row0 col0" >-11.07</td>
#       <td id="T_f054f_row0_col1" class="data row0 col1" >49.88</td>
#       <td id="T_f054f_row0_col2" class="data row0 col2" >-0.22</td>
#       <td id="T_f054f_row0_col3" class="data row0 col3" >-75.89</td>
#       <td id="T_f054f_row0_col4" class="data row0 col4" >-0.22</td>
#       <td id="T_f054f_row0_col5" class="data row0 col5" >31.58</td>
#       <td id="T_f054f_row0_col6" class="data row0 col6" >0.22</td>
#       <td id="T_f054f_row0_col7" class="data row0 col7" >0.77</td>
#       <td id="T_f054f_row0_col8" class="data row0 col8" >1346</td>
#     </tr>
#     <tr>
#       <th id="T_f054f_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_f054f_row1_col0" class="data row1 col0" >-26.48</td>
#       <td id="T_f054f_row1_col1" class="data row1 col1" >68.28</td>
#       <td id="T_f054f_row1_col2" class="data row1 col2" >-0.39</td>
#       <td id="T_f054f_row1_col3" class="data row1 col3" >-95.05</td>
#       <td id="T_f054f_row1_col4" class="data row1 col4" >-0.39</td>
#       <td id="T_f054f_row1_col5" class="data row1 col5" >33.33</td>
#       <td id="T_f054f_row1_col6" class="data row1 col6" >0.27</td>
#       <td id="T_f054f_row1_col7" class="data row1 col7" >1.03</td>
#       <td id="T_f054f_row1_col8" class="data row1 col8" >1331</td>
#     </tr>
#     <tr>
#       <th id="T_f054f_level1_row2" class="row_heading level1 row2" >2</th>
#       <td id="T_f054f_row2_col0" class="data row2 col0" >17.59</td>
#       <td id="T_f054f_row2_col1" class="data row2 col1" >75.09</td>
#       <td id="T_f054f_row2_col2" class="data row2 col2" >0.23</td>
#       <td id="T_f054f_row2_col3" class="data row2 col3" >-73.23</td>
#       <td id="T_f054f_row2_col4" class="data row2 col4" >0.23</td>
#       <td id="T_f054f_row2_col5" class="data row2 col5" >29.41</td>
#       <td id="T_f054f_row2_col6" class="data row2 col6" >0.31</td>
#       <td id="T_f054f_row2_col7" class="data row2 col7" >1.61</td>
#       <td id="T_f054f_row2_col8" class="data row2 col8" >1316</td>
#     </tr>
#     <tr>
#       <th id="T_f054f_level1_row3" class="row_heading level1 row3" >3</th>
#       <td id="T_f054f_row3_col0" class="data row3 col0" >18.06</td>
#       <td id="T_f054f_row3_col1" class="data row3 col1" >46.20</td>
#       <td id="T_f054f_row3_col2" class="data row3 col2" >0.39</td>
#       <td id="T_f054f_row3_col3" class="data row3 col3" >-51.49</td>
#       <td id="T_f054f_row3_col4" class="data row3 col4" >0.39</td>
#       <td id="T_f054f_row3_col5" class="data row3 col5" >31.25</td>
#       <td id="T_f054f_row3_col6" class="data row3 col6" >0.22</td>
#       <td id="T_f054f_row3_col7" class="data row3 col7" >0.82</td>
#       <td id="T_f054f_row3_col8" class="data row3 col8" >1301</td>
#     </tr>
#     <tr>
#       <th id="T_f054f_level1_row4" class="row_heading level1 row4" >4</th>
#       <td id="T_f054f_row4_col0" class="data row4 col0" >18.67</td>
#       <td id="T_f054f_row4_col1" class="data row4 col1" >65.59</td>
#       <td id="T_f054f_row4_col2" class="data row4 col2" >0.28</td>
#       <td id="T_f054f_row4_col3" class="data row4 col3" >-69.96</td>
#       <td id="T_f054f_row4_col4" class="data row4 col4" >0.28</td>
#       <td id="T_f054f_row4_col5" class="data row4 col5" >33.33</td>
#       <td id="T_f054f_row4_col6" class="data row4 col6" >0.36</td>
#       <td id="T_f054f_row4_col7" class="data row4 col7" >1.80</td>
#       <td id="T_f054f_row4_col8" class="data row4 col8" >1285</td>
#     </tr>
#     <tr>
#       <th id="T_f054f_level1_row5" class="row_heading level1 row5" >5</th>
#       <td id="T_f054f_row5_col0" class="data row5 col0" >8.20</td>
#       <td id="T_f054f_row5_col1" class="data row5 col1" >50.74</td>
#       <td id="T_f054f_row5_col2" class="data row5 col2" >0.16</td>
#       <td id="T_f054f_row5_col3" class="data row5 col3" >-59.28</td>
#       <td id="T_f054f_row5_col4" class="data row5 col4" >0.16</td>
#       <td id="T_f054f_row5_col5" class="data row5 col5" >35.71</td>
#       <td id="T_f054f_row5_col6" class="data row5 col6" >0.25</td>
#       <td id="T_f054f_row5_col7" class="data row5 col7" >0.77</td>
# correlation decay RunTime: 0.0275 seconds
# <style type="text/css">
# #T_b51ba th {
#   width: 100px;
# }
# #T_b51ba  td {
#   width: 100px;
# }
# #T_b51ba th {
#   width: auto;
# }
# #T_b51ba  td {
#   width: auto;
# }
# #T_b51ba_row0_col0, #T_b51ba_row0_col1, #T_b51ba_row0_col2, #T_b51ba_row0_col3, #T_b51ba_row0_col4, #T_b51ba_row0_col6, #T_b51ba_row0_col7, #T_b51ba_row1_col0, #T_b51ba_row1_col1, #T_b51ba_row1_col2, #T_b51ba_row1_col3, #T_b51ba_row1_col4, #T_b51ba_row1_col6, #T_b51ba_row1_col7, #T_b51ba_row2_col0, #T_b51ba_row2_col1, #T_b51ba_row2_col2, #T_b51ba_row2_col3, #T_b51ba_row2_col4, #T_b51ba_row2_col6, #T_b51ba_row2_col7, #T_b51ba_row3_col0, #T_b51ba_row3_col1, #T_b51ba_row3_col2, #T_b51ba_row3_col3, #T_b51ba_row3_col4, #T_b51ba_row3_col6, #T_b51ba_row3_col7, #T_b51ba_row4_col0, #T_b51ba_row4_col1, #T_b51ba_row4_col2, #T_b51ba_row4_col3, #T_b51ba_row4_col4, #T_b51ba_row4_col6, #T_b51ba_row4_col7, #T_b51ba_row5_col0, #T_b51ba_row5_col1, #T_b51ba_row5_col2, #T_b51ba_row5_col3, #T_b51ba_row5_col4, #T_b51ba_row5_col6 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_b51ba_row0_col5, #T_b51ba_row3_col5, #T_b51ba_row5_col7 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_b51ba_row0_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_b51ba_row1_col5, #T_b51ba_row2_col5 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_b51ba_row1_col8 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_b51ba_row2_col8 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_b51ba_row3_col8 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_b51ba_row4_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_b51ba_row4_col8 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_b51ba_row5_col5 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_b51ba_row5_col8 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b51ba">
#   <caption>value_chg backtest</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b51ba_level0_col0" class="col_heading level0 col0" >Ann Ret%</th>
#       <th id="T_b51ba_level0_col1" class="col_heading level0 col1" >Ann Vol%</th>
#       <th id="T_b51ba_level0_col2" class="col_heading level0 col2" >Sharpe</th>
#       <th id="T_b51ba_level0_col3" class="col_heading level0 col3" >Max DD%</th>
#       <th id="T_b51ba_level0_col4" class="col_heading level0 col4" >T Stat</th>
#       <th id="T_b51ba_level0_col5" class="col_heading level0 col5" >#|T|>2</th>
#       <th id="T_b51ba_level0_col6" class="col_heading level0 col6" >Mean R^2%</th>
#       <th id="T_b51ba_level0_col7" class="col_heading level0 col7" >Max R^2%</th>
#       <th id="T_b51ba_level0_col8" class="col_heading level0 col8" >Mean Nobs</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ReturnType</th>
#       <th class="index_name level1" >lag</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b51ba_level0_row0" class="row_heading level0 row0" rowspan="6">AlphaReturn</th>
#       <th id="T_b51ba_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_b51ba_row0_col0" class="data row0 col0" >-0.05</td>
#       <td id="T_b51ba_row0_col1" class="data row0 col1" >0.27</td>
#       <td id="T_b51ba_row0_col2" class="data row0 col2" >-0.18</td>
#       <td id="T_b51ba_row0_col3" class="data row0 col3" >-0.78</td>
#       <td id="T_b51ba_row0_col4" class="data row0 col4" >-0.18</td>
#       <td id="T_b51ba_row0_col5" class="data row0 col5" >5.26</td>
#       <td id="T_b51ba_row0_col6" class="data row0 col6" >0.14</td>
#       <td id="T_b51ba_row0_col7" class="data row0 col7" >1.46</td>
#       <td id="T_b51ba_row0_col8" class="data row0 col8" >1346</td>
#     </tr>
#     <tr>
#       <th id="T_b51ba_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_b51ba_row1_col0" class="data row1 col0" >-0.20</td>
#       <td id="T_b51ba_row1_col1" class="data row1 col1" >0.65</td>
#       <td id="T_b51ba_row1_col2" class="data row1 col2" >-0.30</td>
#       <td id="T_b51ba_row1_col3" class="data row1 col3" >-1.78</td>
#       <td id="T_b51ba_row1_col4" class="data row1 col4" >-0.30</td>
#       <td id="T_b51ba_row1_col5" class="data row1 col5" >11.11</td>
#       <td id="T_b51ba_row1_col6" class="data row1 col6" >0.16</td>
#       <td id="T_b51ba_row1_col7" class="data row1 col7" >1.13</td>
#       <td id="T_b51ba_row1_col8" class="data row1 col8" >1331</td>
#     </tr>
#     <tr>
#       <th id="T_b51ba_level1_row2" class="row_heading level1 row2" >2</th>
#       <td id="T_b51ba_row2_col0" class="data row2 col0" >-0.04</td>
#       <td id="T_b51ba_row2_col1" class="data row2 col1" >0.44</td>
#       <td id="T_b51ba_row2_col2" class="data row2 col2" >-0.08</td>
#       <td id="T_b51ba_row2_col3" class="data row2 col3" >-0.73</td>
#       <td id="T_b51ba_row2_col4" class="data row2 col4" >-0.08</td>
#       <td id="T_b51ba_row2_col5" class="data row2 col5" >11.76</td>
#       <td id="T_b51ba_row2_col6" class="data row2 col6" >0.18</td>
#       <td id="T_b51ba_row2_col7" class="data row2 col7" >0.92</td>
#       <td id="T_b51ba_row2_col8" class="data row2 col8" >1316</td>
#     </tr>
#     <tr>
#       <th id="T_b51ba_level1_row3" class="row_heading level1 row3" >3</th>
#       <td id="T_b51ba_row3_col0" class="data row3 col0" >0.25</td>
#       <td id="T_b51ba_row3_col1" class="data row3 col1" >0.30</td>
#       <td id="T_b51ba_row3_col2" class="data row3 col2" >0.85</td>
#       <td id="T_b51ba_row3_col3" class="data row3 col3" >-0.09</td>
#       <td id="T_b51ba_row3_col4" class="data row3 col4" >0.85</td>
#       <td id="T_b51ba_row3_col5" class="data row3 col5" >6.25</td>
#       <td id="T_b51ba_row3_col6" class="data row3 col6" >0.12</td>
#       <td id="T_b51ba_row3_col7" class="data row3 col7" >0.44</td>
#       <td id="T_b51ba_row3_col8" class="data row3 col8" >1301</td>
#     </tr>
#     <tr>
#       <th id="T_b51ba_level1_row4" class="row_heading level1 row4" >4</th>
#       <td id="T_b51ba_row4_col0" class="data row4 col0" >-0.09</td>
#       <td id="T_b51ba_row4_col1" class="data row4 col1" >0.47</td>
#       <td id="T_b51ba_row4_col2" class="data row4 col2" >-0.19</td>
#       <td id="T_b51ba_row4_col3" class="data row4 col3" >-0.58</td>
#       <td id="T_b51ba_row4_col4" class="data row4 col4" >-0.19</td>
#       <td id="T_b51ba_row4_col5" class="data row4 col5" >20.00</td>
#       <td id="T_b51ba_row4_col6" class="data row4 col6" >0.19</td>
#       <td id="T_b51ba_row4_col7" class="data row4 col7" >0.90</td>
#       <td id="T_b51ba_row4_col8" class="data row4 col8" >1285</td>
#     </tr>
#     <tr>
#       <th id="T_b51ba_level1_row5" class="row_heading level1 row5" >5</th>
#       <td id="T_b51ba_row5_col0" class="data row5 col0" >0.25</td>
#       <td id="T_b51ba_row5_col1" class="data row5 col1" >0.36</td>
#       <td id="T_b51ba_row5_col2" class="data row5 col2" >0.71</td>
#       <td id="T_b51ba_row5_col3" class="data row5 col3" >-0.33</td>
#       <td id="T_b51ba_row5_col4" class="data row5 col4" >0.71</td>
#       <td id="T_b51ba_row5_col5" class="data row5 col5" >35.71</td>
#       <td id="T_b51ba_row5_col6" class="data row5 col6" >1.15</td>
#       <td id="T_b51ba_row5_col7" class="data row5 col7" >7.58</td>
#       <td id="T_b51ba_row5_col8" class="data row5 col8" >1269</td>
#     </tr>
#   </tbody>
# </table>
# correlation decay RunTime: 0.0264 seconds
# <style type="text/css">
# #T_41407 th {
#   width: 100px;
# }
# #T_41407  td {
#   width: 100px;
# }
# #T_41407 th {
#   width: auto;
# }
# #T_41407  td {
#   width: auto;
# }
# #T_41407_row0_col0, #T_41407_row0_col1, #T_41407_row0_col2, #T_41407_row0_col3, #T_41407_row0_col4, #T_41407_row0_col6, #T_41407_row0_col7, #T_41407_row1_col0, #T_41407_row1_col1, #T_41407_row1_col2, #T_41407_row1_col3, #T_41407_row1_col4, #T_41407_row1_col6, #T_41407_row1_col7, #T_41407_row2_col0, #T_41407_row2_col1, #T_41407_row2_col2, #T_41407_row2_col3, #T_41407_row2_col4, #T_41407_row2_col6, #T_41407_row2_col7, #T_41407_row3_col0, #T_41407_row3_col1, #T_41407_row3_col2, #T_41407_row3_col3, #T_41407_row3_col4, #T_41407_row3_col6, #T_41407_row3_col7, #T_41407_row4_col0, #T_41407_row4_col2, #T_41407_row4_col3, #T_41407_row4_col4, #T_41407_row4_col6, #T_41407_row5_col0, #T_41407_row5_col1, #T_41407_row5_col2, #T_41407_row5_col3, #T_41407_row5_col4, #T_41407_row5_col6, #T_41407_row5_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_41407_row0_col5, #T_41407_row1_col5 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_41407_row0_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_41407_row1_col8 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_41407_row2_col5, #T_41407_row3_col5, #T_41407_row4_col1, #T_41407_row4_col7 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_41407_row2_col8 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_41407_row3_col8 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_41407_row4_col5 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_41407_row4_col8 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_41407_row5_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_41407_row5_col8 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_41407">
#   <caption>mgrno_cnt_ratio_chg backtest</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41407_level0_col0" class="col_heading level0 col0" >Ann Ret%</th>
#       <th id="T_41407_level0_col1" class="col_heading level0 col1" >Ann Vol%</th>
#       <th id="T_41407_level0_col2" class="col_heading level0 col2" >Sharpe</th>
#       <th id="T_41407_level0_col3" class="col_heading level0 col3" >Max DD%</th>
#       <th id="T_41407_level0_col4" class="col_heading level0 col4" >T Stat</th>
#       <th id="T_41407_level0_col5" class="col_heading level0 col5" >#|T|>2</th>
#       <th id="T_41407_level0_col6" class="col_heading level0 col6" >Mean R^2%</th>
#       <th id="T_41407_level0_col7" class="col_heading level0 col7" >Max R^2%</th>
#       <th id="T_41407_level0_col8" class="col_heading level0 col8" >Mean Nobs</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ReturnType</th>
#       <th class="index_name level1" >lag</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41407_level0_row0" class="row_heading level0 row0" rowspan="6">AlphaReturn</th>
#       <th id="T_41407_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_41407_row0_col0" class="data row0 col0" >0.05</td>
#       <td id="T_41407_row0_col1" class="data row0 col1" >1.21</td>
#       <td id="T_41407_row0_col2" class="data row0 col2" >0.04</td>
#       <td id="T_41407_row0_col3" class="data row0 col3" >-3.26</td>
#       <td id="T_41407_row0_col4" class="data row0 col4" >0.04</td>
#       <td id="T_41407_row0_col5" class="data row0 col5" >10.53</td>
#       <td id="T_41407_row0_col6" class="data row0 col6" >0.15</td>
#       <td id="T_41407_row0_col7" class="data row0 col7" >0.91</td>
#       <td id="T_41407_row0_col8" class="data row0 col8" >1346</td>
#     </tr>
#     <tr>
#       <th id="T_41407_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_41407_row1_col0" class="data row1 col0" >0.75</td>
#       <td id="T_41407_row1_col1" class="data row1 col1" >1.35</td>
#       <td id="T_41407_row1_col2" class="data row1 col2" >0.56</td>
#       <td id="T_41407_row1_col3" class="data row1 col3" >-1.77</td>
#       <td id="T_41407_row1_col4" class="data row1 col4" >0.56</td>
#       <td id="T_41407_row1_col5" class="data row1 col5" >11.11</td>
#       <td id="T_41407_row1_col6" class="data row1 col6" >0.10</td>
#       <td id="T_41407_row1_col7" class="data row1 col7" >0.46</td>
#       <td id="T_41407_row1_col8" class="data row1 col8" >1331</td>
#     </tr>
#     <tr>
#       <th id="T_41407_level1_row2" class="row_heading level1 row2" >2</th>
#       <td id="T_41407_row2_col0" class="data row2 col0" >0.72</td>
#       <td id="T_41407_row2_col1" class="data row2 col1" >1.36</td>
#       <td id="T_41407_row2_col2" class="data row2 col2" >0.53</td>
#       <td id="T_41407_row2_col3" class="data row2 col3" >-1.09</td>
#       <td id="T_41407_row2_col4" class="data row2 col4" >0.53</td>
#       <td id="T_41407_row2_col5" class="data row2 col5" >5.88</td>
#       <td id="T_41407_row2_col6" class="data row2 col6" >0.14</td>
#       <td id="T_41407_row2_col7" class="data row2 col7" >1.23</td>
#       <td id="T_41407_row2_col8" class="data row2 col8" >1316</td>
#     </tr>
#     <tr>
#       <th id="T_41407_level1_row3" class="row_heading level1 row3" >3</th>
#       <td id="T_41407_row3_col0" class="data row3 col0" >-0.63</td>
#       <td id="T_41407_row3_col1" class="data row3 col1" >1.19</td>
#       <td id="T_41407_row3_col2" class="data row3 col2" >-0.53</td>
#       <td id="T_41407_row3_col3" class="data row3 col3" >-3.56</td>
#       <td id="T_41407_row3_col4" class="data row3 col4" >-0.53</td>
#       <td id="T_41407_row3_col5" class="data row3 col5" >6.25</td>
#       <td id="T_41407_row3_col6" class="data row3 col6" >0.13</td>
#       <td id="T_41407_row3_col7" class="data row3 col7" >0.99</td>
#       <td id="T_41407_row3_col8" class="data row3 col8" >1301</td>
#     </tr>
#     <tr>
#       <th id="T_41407_level1_row4" class="row_heading level1 row4" >4</th>
#       <td id="T_41407_row4_col0" class="data row4 col0" >1.18</td>
#       <td id="T_41407_row4_col1" class="data row4 col1" >1.83</td>
#       <td id="T_41407_row4_col2" class="data row4 col2" >0.65</td>
#       <td id="T_41407_row4_col3" class="data row4 col3" >-1.47</td>
#       <td id="T_41407_row4_col4" class="data row4 col4" >0.65</td>
#       <td id="T_41407_row4_col5" class="data row4 col5" >26.67</td>
#       <td id="T_41407_row4_col6" class="data row4 col6" >0.28</td>
#       <td id="T_41407_row4_col7" class="data row4 col7" >2.13</td>
#       <td id="T_41407_row4_col8" class="data row4 col8" >1285</td>
#     </tr>
#     <tr>
#       <th id="T_41407_level1_row5" class="row_heading level1 row5" >5</th>
#       <td id="T_41407_row5_col0" class="data row5 col0" >0.22</td>
#       <td id="T_41407_row5_col1" class="data row5 col1" >1.24</td>
#       <td id="T_41407_row5_col2" class="data row5 col2" >0.18</td>
#       <td id="T_41407_row5_col3" class="data row5 col3" >-2.30</td>
#       <td id="T_41407_row5_col4" class="data row5 col4" >0.18</td>
#       <td id="T_41407_row5_col5" class="data row5 col5" >21.43</td>
#       <td id="T_41407_row5_col6" class="data row5 col6" >0.17</td>
#       <td id="T_41407_row5_col7" class="data row5 col7" >0.89</td>
#       <td id="T_41407_row5_col8" class="data row5 col8" >1269</td>
#     </tr>
#   </tbody>
# </table>
# correlation decay RunTime: 0.0282 seconds

# %%
risk_factors = ['future_ret', 'dolvol', 'div12m_me', 'ret_1_0', 'ret_6_1', 'ret_12_1', 'ebit_sale', 'ebit_bev', 'beta_60m', 
              'ami_126d', 'betadown_252d', 'rvolhl_21d']
hmap = build_corr_heatmap(signal_df, others=risk_factors, factors=signal_cols)
styled_df = Table(round(hmap, 1), title=f'Rank Corr of Factors & Risk Factors (%)', number_fmt="{:.1f}")
display(styled_df)
# Out:
# <style type="text/css">
# #T_39eee th {
#   width: 100px;
# }
# #T_39eee  td {
#   width: 100px;
# }
# #T_39eee_row0_col0, #T_39eee_row1_col1, #T_39eee_row2_col2, #T_39eee_row3_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_39eee_row0_col1, #T_39eee_row1_col0 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_39eee_row0_col2, #T_39eee_row2_col0 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_39eee_row0_col3, #T_39eee_row3_col0 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_39eee_row1_col2, #T_39eee_row2_col1 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_39eee_row1_col3, #T_39eee_row3_col1, #T_39eee_row5_col3, #T_39eee_row12_col0, #T_39eee_row15_col0 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_39eee_row2_col3, #T_39eee_row3_col2 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_39eee_row4_col0, #T_39eee_row15_col1 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_39eee_row4_col1, #T_39eee_row9_col1 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_39eee_row4_col2, #T_39eee_row5_col2 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_39eee_row4_col3 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_39eee_row5_col0 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_39eee_row5_col1 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_39eee_row6_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_39eee_row6_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_39eee_row6_col2 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_39eee_row6_col3, #T_39eee_row15_col3 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_39eee_row7_col0, #T_39eee_row14_col1 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_39eee_row7_col1 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_39eee_row7_col2 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_39eee_row7_col3, #T_39eee_row10_col0, #T_39eee_row11_col3 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_39eee_row8_col0 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_39eee_row8_col1, #T_39eee_row12_col1 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_39eee_row8_col2 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_39eee_row8_col3 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_39eee_row9_col0 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_39eee_row9_col2 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_39eee_row9_col3 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_39eee_row10_col1 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_39eee_row10_col2 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_39eee_row10_col3 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_39eee_row11_col0, #T_39eee_row11_col1, #T_39eee_row11_col2, #T_39eee_row12_col2, #T_39eee_row12_col3 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_39eee_row13_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_39eee_row13_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_39eee_row13_col2 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_39eee_row13_col3, #T_39eee_row14_col3 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_39eee_row14_col0 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_39eee_row14_col2 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_39eee_row15_col2 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# </style>
# <table id="T_39eee">
#   <caption>Rank Corr of Factors & Risk Factors (%)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39eee_level0_col0" class="col_heading level0 col0" >weight</th>
#       <th id="T_39eee_level0_col1" class="col_heading level0 col1" >weight_diff</th>
#       <th id="T_39eee_level0_col2" class="col_heading level0 col2" >value_chg</th>
#       <th id="T_39eee_level0_col3" class="col_heading level0 col3" >mgrno_cnt_ratio_chg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39eee_level0_row0" class="row_heading level0 row0" >weight</th>
#       <td id="T_39eee_row0_col0" class="data row0 col0" >100.0</td>
#       <td id="T_39eee_row0_col1" class="data row0 col1" >67.5</td>
#       <td id="T_39eee_row0_col2" class="data row0 col2" >10.9</td>
#       <td id="T_39eee_row0_col3" class="data row0 col3" >6.9</td>
#     </tr>
#     <tr>
#       <th id="T_39eee_level0_row1" class="row_heading level0 row1" >weight_diff</th>
#       <td id="T_39eee_row1_col0" class="data row1 col0" >67.5</td>
#       <td id="T_39eee_row1_col1" class="data row1 col1" >100.0</td>
#       <td id="T_39eee_row1_col2" class="data row1 col2" >20.8</td>
#       <td id="T_39eee_row1_col3" class="data row1 col3" >6.7</td>
#     </tr>
#     <tr>
#       <th id="T_39eee_level0_row2" class="row_heading level0 row2" >value_chg</th>
#       <td id="T_39eee_row2_col0" class="data row2 col0" >10.9</td>
#       <td id="T_39eee_row2_col1" class="data row2 col1" >20.8</td>
#       <td id="T_39eee_row2_col2" class="data row2 col2" >100.0</td>
#       <td id="T_39eee_row2_col3" class="data row2 col3" >32.7</td>
#     </tr>
#     <tr>
#       <th id="T_39eee_level0_row3" class="row_heading level0 row3" >mgrno_cnt_ratio_chg</th>
#       <td id="T_39eee_row3_col0" class="data row3 col0" >6.9</td>
#       <td id="T_39eee_row3_col1" class="data row3 col1" >6.7</td>
#       <td id="T_39eee_row3_col2" class="data row3 col2" >32.7</td>
#       <td id="T_39eee_row3_col3" class="data row3 col3" >100.0</td>
#     </tr>
#     <tr>
#       <th id="T_39eee_level0_row4" class="row_heading level0 row4" >future_ret</th>
#       <td id="T_39eee_row4_col0" class="data row4 col0" >3.4</td>
#       <td id="T_39eee_row4_col1" class="data row4 col1" >2.3</td>
#       <td id="T_39eee_row4_col2" class="data row4 col2" >1.3</td>
#       <td id="T_39eee_row4_col3" class="data row4 col3" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_39eee_level0_row5" class="row_heading level0 row5" >dolvol</th>
#       <td id="T_39eee_row5_col0" class="data row5 col0" >18.7</td>
#       <td id="T_39eee_row5_col1" class="data row5 col1" >22.3</td>
#       <td id="T_39eee_row5_col2" class="data row5 col2" >1.5</td>
#       <td id="T_39eee_row5_col3" class="data row5 col3" >6.4</td>
#     </tr>
#     <tr>
#       <th id="T_39eee_level0_row6" class="row_heading level0 row6" >div12m_me</th>
#       <td id="T_39eee_row6_col0" class="data row6 col0" >-20.5</td>
#       <td id="T_39eee_row6_col1" class="data row6 col1" >-10.5</td>
#       <td id="T_39eee_row6_col2" class="data row6 col2" >-6.5</td>
#       <td id="T_39eee_row6_col3" class="data row6 col3" >-5.7</td>
#     </tr>
#     <tr>
#       <th id="T_39eee_level0_row7" class="row_heading level0 row7" >ret_1_0</th>
#       <td id="T_39eee_row7_col0" class="data row7 col0" >5.1</td>
#       <td id="T_39eee_row7_col1" class="data row7 col1" >11.3</td>
#       <td id="T_39eee_row7_col2" class="data row7 col2" >41.0</td>
#       <td id="T_39eee_row7_col3" class="data row7 col3" >0.2</td>
#     </tr>
#     <tr>
#       <th id="T_39eee_level0_row8" class="row_heading level0 row8" >ret_6_1</th>
#       <td id="T_39eee_row8_col0" class="data row8 col0" >12.3</td>
#       <td id="T_39eee_row8_col1" class="data row8 col1" >2.9</td>
#       <td id="T_39eee_row8_col2" class="data row8 col2" >40.0</td>
#       <td id="T_39eee_row8_col3" class="data row8 col3" >39.6</td>
#     </tr>
#     <tr>
#       <th id="T_39eee_level0_row9" class="row_heading level0 row9" >ret_12_1</th>
#       <td id="T_39eee_row9_col0" class="data row9 col0" >13.5</td>
#       <td id="T_39eee_row9_col1" class="data row9 col1" >2.4</td>
#       <td id="T_39eee_row9_col2" class="data row9 col2" >26.0</td>
#       <td id="T_39eee_row9_col3" class="data row9 col3" >33.3</td>
#     </tr>
#     <tr>
#       <th id="T_39eee_level0_row10" class="row_heading level0 row10" >ebit_sale</th>
#       <td id="T_39eee_row10_col0" class="data row10 col0" >0.1</td>
#       <td id="T_39eee_row10_col1" class="data row10 col1" >-0.8</td>
#       <td id="T_39eee_row10_col2" class="data row10 col2" >-2.0</td>
#       <td id="T_39eee_row10_col3" class="data row10 col3" >0.4</td>
#     </tr>
#     <tr>
#       <th id="T_39eee_level0_row11" class="row_hea
